# %% [markdown]
# # Compare churn count with respect to gender.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_excel(r"C:\Users\HP\OneDrive\Desktop\Telco-Customer-Churn.xlsx")

# %%
# Read and count
df=pd.DataFrame(data)
a=df.value_counts('gender')
print(a)
# Out:
# gender
# Male      3555
# Female    3488
# dtype: int64

# %%
df['gender'].value_counts().plot(kind='bar')
plt.xlabel('gender')       
plt.hist(['Female','Male'],bins=[60,70,80,100,120],label=['Female','Male'])
plt.grid(axis='y')
plt.ylim((1000,4000))
plt.legend();

# %% [markdown]
# # Findout how many female senior citizen there in the dataset

# %%
data=display(data.loc[(data.SeniorCitizen == 1) & (data.gender=="Female")])
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 30    3841-NFECX  Female              1     Yes         No      71
# 50    8012-SOUDQ  Female              1      No         No      43
# 52    6575-SUVOI  Female              1     Yes         No      25
# 53    7495-OOKFY  Female              1     Yes         No       8
# 54    4667-QONEA  Female              1     Yes        Yes      60
# ...          ...     ...            ...     ...        ...     ...
# 6993  6583-QGCSI  Female              1     Yes         No      50
# 7008  1980-KXVPM  Female              1      No         No       3
# 7010  0723-DRCLG  Female              1     Yes         No       1
# 7023  1035-IPQPU  Female              1     Yes         No      63
# 7029  2235-DWLJU  Female              1      No         No       6
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 30            Yes               Yes     Fiber optic            Yes  ...
# ...

# %%
df['gender'].value_counts()['Female']
# Out:
# 3488

# %% [markdown]
# # Find out which contract is preferred by Senior Citizens most

# %%
data=display(data.loc[(data.SeniorCitizen == 1) & (data.Contract=='Month-to-month')])
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 20    8779-QRDMV    Male              1      No         No       1
# 31    4929-XIHVW    Male              1     Yes         No       2
# 34    3413-BMNZE    Male              1      No         No       1
# 50    8012-SOUDQ  Female              1      No         No      43
# 52    6575-SUVOI  Female              1     Yes         No      25
# ...          ...     ...            ...     ...        ...     ...
# 7015  0666-UXTJO    Male              1     Yes         No      34
# 7023  1035-IPQPU  Female              1     Yes         No      63
# 7029  2235-DWLJU  Female              1      No         No       6
# 7032  6894-LFHLY    Male              1      No         No       1
# 7041  8361-LTMKD    Male              1     Yes         No       4
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 20             No  No phone service             DSL             No  ...
# ...

# %%
df1=df['Contract'].value_counts()['Month-to-month']
print(df1)
df2=df['Contract'].value_counts()['One year']
print(df2)
df2=df['Contract'].value_counts()['One year']
print(df2)
# Out:
# 3875
# 1473
# 1473

# %%
import matplotlib.pyplot as plt

data={'Month-to-month':3875,'One year':1473,'Two year':1695}
names = list(data.keys())
values = list(data.values())
plt.grid(axis='y')
plt.bar(range(len(data)), values, tick_label=names)
plt.show()
